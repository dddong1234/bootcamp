# %%
data = {
    '이름': ['철수', '영희', '민수', '지영', '지수'],
    '나이': [25, 30, 35, 28, 29],
    '성별': ['남', '여', '남', '여', '여'],
    '성적': [80, 90, 75, 85, 95]
}
df = pd.DataFrame(data)

# %%
school = pd.
df['학교']=school
df_school.loc['철수':'민수']='A학교'
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 school = []
# ----> 2 df['학교']=school
#       3 df_school.loc['철수':'민수']='A학교'
#
# File /mnt/c/Users/sdh08/PycharmProjects/PythonProject1/.venv/lib/python3.11/site-packages/pandas/core/frame.py:4672, in DataFrame.__setitem__(self, key, value)
#    4669     self._setitem_array([key], value)
#    4670 else:
#    4671     # set column
# -> 4672     self._set_item(key, value)
#
# File /mnt/c/Users/sdh08/PycharmProjects/PythonProject1/.venv/lib/python3.11/site-packages/pandas/core/frame.py:4872, in DataFrame._set_item(self, key, value)
#    4862 def _set_item(self, key, value) -> None:
#    4863     """
#    4864     Add series to DataFrame in specified column.
#    4865
#    (...)   4870     ensure homogeneity.
#    4871     """
# -> 4872     value, refs = self._sanitize_column(value)
#    4874     if (
# ...
