# %%
from dotenv import load_dotenv
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_openai import ChatOpenAI

load_dotenv()

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature= 0
)

prompt = ChatPromptTemplate.from_template(
    "당신은 {role} 전문가입니다. {question}에 답해주세요."
)

parser = StrOutputParser()

chain = prompt | llm | parser

data = {
    "role":"건강",
    "question":"여름철식중독"
}

result = chain.invoke(data)
print('\n\n'.join(result.split('\n\n')[1:4]))
# Out:
# 1. **위생적인 손 씻기**: 음식을 조리하기 전과 후, 식사 전, 화장실 사용 후에는 반드시 손을 씻어야 합니다. 비누와 물로 20초 이상 씻는 것이 좋습니다.
#
# 2. **식품 보관**: 냉장고의 온도를 4도 이하로 유지하고, 조리된 음식은 2시간 이내에 냉장 보관해야 합니다. 특히 고기, 해산물, 유제품은 더욱 주의해야 합니다.
#
# 3. **조리 시 충분한 열처리**: 고기와 해산물은 내부 온도가 75도 이상이 되도록 충분히 익혀야 합니다. 생고기와 익힌 음식을 분리하여 조리하는 것이 좋습니다.

# %%
response = llm.invoke("안녕하세요")
print(response.content)
# Out:
# 안녕하세요! 어떻게 도와드릴까요?
